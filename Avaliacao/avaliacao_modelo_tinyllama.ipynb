# %% [markdown]
# # 📊 Avaliação de Modelo Fine-Tuned com LoRA do Modelo baseado em TinyLlama/TinyLlama-1.1B-Chat-v1.0
#
# Este notebook avalia um modelo de linguagem fine-tuned usando as principais métricas de NLP. O dataset utilizado manual de NR 12 (`dataset.jsonl`) e o modelo base é o `TinyLlama/TinyLlama-1.1B-Chat-v1.0` com adaptadores LoRA.
#
# ---
#
# ## 🗺️ Métricas Avaliadas
#
# | Métrica | Foco | Intervalo Típico |
# |---|---|---|
# | **Perplexidade (PPL)** | Capacidade preditiva do modelo | Menor = melhor |
# | **BLEU** | Precisão de n-gramas vs. referência | 0–100 (maior = melhor) |
# | **ROUGE** | Recall de sobreposição de conteúdo | 0–1 (maior = melhor) |
# | **Fidelidade (Faithfulness)** | Se a resposta é fiel ao contexto | 0–1 (maior = melhor) |
# | **Relevância da Resposta** | Se a resposta é útil à pergunta | 0–1 (maior = melhor) |
# | **Aderência ao Plano** | Se o agente segue o plano de ação | 0–1 (maior = melhor) |
#
# ---

# %% [markdown]
# ## 1 — Instalação e Importação
#
# Instalamos todas as bibliotecas necessárias.

# %%
# ============================================================
#  INSTALAÇÃO DE DEPENDÊNCIAS
# ============================================================

# !pip install -q transformers peft torch sacrebleu rouge-score nltk pandas \
             matplotlib seaborn tqdm

import nltk
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)

print('✅ Todas as dependências instaladas com sucesso!')
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 10.2 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
# ✅ Todas as dependências instaladas com sucesso!

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    # !pip install --upgrade torchao>=0.16.0

# %%
# ============================================================
#  IMPORTAÇÕES
# ============================================================

import json
import math
import re
import warnings
from collections import Counter

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from tqdm import tqdm

# Transformers & PEFT
from transformers import AutoModelForCausalLM, AutoTokenizer
#from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from peft import PeftModel

# Métricas NLP
from sacrebleu.metrics import BLEU
from rouge_score import rouge_scorer
from nltk.tokenize import word_tokenize

warnings.filterwarnings('ignore')

# Configuração de visualização
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('Set2')

print('✅ Importações concluídas!')
print(f'   PyTorch: {torch.__version__}')
print(f'   Dispositivo disponível: {"GPU (CUDA)" if torch.cuda.is_available() else "CPU"}')
# Out:
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# ✅ Importações concluídas!
#    PyTorch: 2.11.0+cu128
#    Dispositivo disponível: GPU (CUDA)

# %% [markdown]
# ## 📂 2 — Carregamento do Dataset
#
# Lemos o arquivo `dataset.jsonl`. Cada linha contém:
# - **`instruction`**: o que o usuário quer saber
# - **`input`**: contexto adicional (veículo, modelo, etc.)
# - **`output`**: resposta esperada (ground truth)

# %%
DATASET_PATH = '/content/dataset.jsonl'
samples = []
with open(DATASET_PATH, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            samples.append(json.loads(line))

print(f'✅ Dataset carregado com {len(samples)} amostras.\n')

# Exibição amigável das primeiras amostras
df_raw = pd.DataFrame(samples)
df_raw[['Instruction', 'Output']].head(3).style \
    .set_caption('📋 Primeiras amostras do dataset') \
    .set_properties(**{'text-align': 'left', 'white-space': 'pre-wrap'})
# Out:
# ✅ Dataset carregado com 416 amostras.
# <style type="text/css">
# #T_e00b5_row0_col0, #T_e00b5_row0_col1, #T_e00b5_row1_col0, #T_e00b5_row1_col1, #T_e00b5_row2_col0, #T_e00b5_row2_col1 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_e00b5" class="dataframe">
#   <caption>📋 Primeiras amostras do dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e00b5_level0_col0" class="col_heading level0 col0" >Instruction</th>
#       <th id="T_e00b5_level0_col1" class="col_heading level0 col1" >Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e00b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e00b5_row0_col0" class="data row0 col0" >Qual é a principal característica técnica abordada no manual para sistemas de comandos de segurança?</td>
#       <td id="T_e00b5_row0_col1" class="data row0 col1" >O manual aborda principalmente as características técnicas necessárias para o projeto e instalação de sistemas de comandos de segurança em máquinas e equipamentos, enfocando tanto sistemas simples quanto redundantes com dois canais, conforme a Norma Regulamentadora nº 12 (NR-12).</td>
#     </tr>
#     <tr>
#       <th id="T_e00b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e00b5_row1_col0" class="data row1 col0" >Quais são as condições para a redundância dos dispositivos de segurança em circuitos elétricos de chave de partida?</td>
#       <td id="T_e00b5_row1_col1" class="data row1 col1" >Para a redundância dos dispositivos de segurança em circuitos elétricos de chave de partida, conforme a NR-12, os dispositivos devem possuir estrutura redundante (item 12.4.14) e permitir que as falhas que comprometam a função de segurança sejam monitoradas.</td>
#     </tr>
#     <tr>
#       <th id="T_e00b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e00b5_row2_col0" class="data row2 col0" >Como as máquinas devem ser dimensionadas de acordo com a NR-12?</td>
#       <td id="T_e00b5_row2_col1" class="data row2 col1" >As máquinas devem ser adequadamente dimensionadas em conformidade com as normas técnicas oficiais ou as normas internacionais aplicáveis, conforme estabelecido na NR-12.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🤖 Célula 4 — Carregamento do Modelo Fine-Tuned
#
# Carregamos o modelo base `TinyLlama/TinyLlama-1.1B-Chat-v1.0` e aplicamos os adaptadores LoRA salvos em `lora_finetuned_model/`.

# %%
# ============================================================
#  CARREGAMENTO DO MODELO FINE-TUNED (LoRA)
# ============================================================

MODEL_BASE      = 'TinyLlama/TinyLlama-1.1B-Chat-v1.0'
LORA_MODEL_PATH = 'lora_finetuned_model'    # mesmo diretório gerado pelo lora_modelo_tinyllama
TOKENIZER_PATH  = 'tinyllama_tokenizer'           # nome salvo pelo lora_modelo_tinyllama
base_model = AutoModelForCausalLM.from_pretrained(MODEL_BASE)

print('⏳ Carregando tokenizer...')
finetuned_tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

if finetuned_tokenizer.pad_token is None:
    finetuned_tokenizer.pad_token = finetuned_tokenizer.eos_token
    print('   ⚠️  pad_token não encontrado — usando eos_token como pad_token.')

print('⏳ Carregando modelo base...')

print('⏳ Aplicando adaptadores LoRA...')
finetuned_model = PeftModel.from_pretrained(base_model, LORA_MODEL_PATH)
finetuned_model.eval()  # Modo de inferência (desativa dropout)

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
finetuned_model = finetuned_model.to(DEVICE)

# Contagem de parâmetros
total_params    = sum(p.numel() for p in finetuned_model.parameters())
trainable_params = sum(p.numel() for p in finetuned_model.parameters() if p.requires_grad)

print(f'\n✅ Modelo carregado no dispositivo: {DEVICE}')
print(f'   Parâmetros totais   : {total_params:,}')
print(f'   Parâmetros LoRA     : {trainable_params:,}')
print(f'   Redução LoRA        : {(1 - trainable_params/total_params)*100:.1f}% do total')
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ⏳ Carregando tokenizer...
# ⏳ Carregando modelo base...
# ⏳ Aplicando adaptadores LoRA...
#
# ✅ Modelo carregado no dispositivo: cuda
#    Parâmetros totais   : 1,104,553,984
#    Parâmetros LoRA     : 0
#    Redução LoRA        : 100.0% do total

# %% [markdown]
# ## 4 — Função de Geração de Respostas
#
# Definimos a função central que constrói o **prompt** e chama o modelo para gerar uma resposta.

# %%
def build_prompt(instruction: str, input_text: str = '') -> str:
    """Monta o prompt para o TinyLlama (Causal LM)."""
    if input_text.strip():
        return f"Instruction: {instruction}\nInput: {input_text}\nOutput:"
    return f"Instruction: {instruction}\nOutput:"


def generate_response(
    model,
    tokenizer,
    instruction: str,
    input_text: str = '',
    max_new_tokens: int = 200,
    temperature: float = 0.7,
    top_p: float = 0.9,
) -> str:
    prompt = build_prompt(instruction, input_text)
    inputs = tokenizer(
        prompt,
        return_tensors='pt',
        truncation=True,
        max_length=192,         # MAX_INPUT_LENGTH do lora_modelo_tinyllama
    ).to(DEVICE)

    with torch.no_grad():
        output_ids = model.generate(
            input_ids=inputs['input_ids'],
            attention_mask=inputs['attention_mask'],
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            top_p=top_p,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,  # Causal LM: necessário para evitar warning
        )

    # Causal LM: a saída inclui o prompt — extraímos apenas a parte após "Output:"
    full_output = tokenizer.decode(output_ids[0], skip_special_tokens=True)
    resposta = full_output.split("Output:")[-1].strip()
    return resposta

print('✅ Funções de geração definidas!')

# --- TESTE RÁPIDO ---
sample = samples[0]
test_response = generate_response(
    finetuned_model, finetuned_tokenizer,
    sample['Instruction']
)
print(f'\n🧪 Teste rápido com a primeira amostra:')
print(f'   📌 Instrução : {sample["Instruction"]}')
print(f'   ✅ Esperado  : {sample["Output"][:80]}...')
print(f'   🤖 Gerado    : {test_response[:80]}...')
# Out:
# ✅ Funções de geração definidas!
# [transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🧪 Teste rápido com a primeira amostra:
#    📌 Instrução : Qual é a principal característica técnica abordada no manual para sistemas de comandos de segurança?
#    ✅ Esperado  : O manual aborda principalmente as características técnicas necessárias para o pr...
#    🤖 Gerado    : No manual, o uso de sistemas de comandos de segurança com abertura e fechamento ...

# %% [markdown]
# ## 5 — Métrica 1: Perplexidade (PPL)
#
# ### O que é?
# A **Perplexidade** mede o quão surpreso o modelo fica ao ver o texto de referência. É calculada a partir da **log-verossimilhança negativa média** por token:
#
# $$\text{PPL} = \exp\left(-\frac{1}{N}\sum_{i=1}^{N} \log P(w_i | w_1, \dots, w_{i-1})\right)$$
#
# - **PPL baixa** → o modelo prevê bem o texto de referência → melhor desempenho.
# - **PPL = 1** → previsão perfeita (impossível na prática).
# - **PPL alta** → o modelo está "confuso" com o texto.
#
# ### Como é calculada aqui?
# Para cada amostra, passamos o **texto de referência** (output esperado) pelo modelo e calculamos a loss (cross-entropy), depois convertemos para PPL.

# %%
def compute_perplexity_for_sample(
    model, tokenizer, instruction: str, input_text: str, reference: str
) -> float:
    """
    Calcula PPL para um modelo Causal LM (TinyLlama):
    - O texto completo (prompt + referência) é passado ao modelo como input_ids
    - Os labels são o mesmo tensor, mas com -100 nos tokens do prompt
      (só a parte da resposta contribui para a loss)
    """
    prompt = build_prompt(instruction, input_text)

    # Tokeniza prompt e referência separadamente para saber o comprimento do prompt
    prompt_ids = tokenizer(
        prompt,
        return_tensors='pt',
        truncation=True,
        max_length=192,
        add_special_tokens=True,
    )['input_ids']

    ref_ids = tokenizer(
        reference,
        return_tensors='pt',
        truncation=True,
        max_length=128,
        add_special_tokens=False,  # evita EOS duplicado
    )['input_ids']

    # Concatena prompt + referência como input
    input_ids = torch.cat([prompt_ids, ref_ids], dim=1).to(DEVICE)

    # Labels: -100 na posição do prompt, tokens reais na posição da referência
    labels = torch.cat([
        torch.full_like(prompt_ids, -100),
        ref_ids,
    ], dim=1).to(DEVICE)

    # Trunca para o limite do modelo (evita OOM)
    max_len = 320
    input_ids = input_ids[:, :max_len]
    labels    = labels[:, :max_len]

    attention_mask = torch.ones_like(input_ids)

    with torch.no_grad():
        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels,
        )
        loss = outputs.loss

    return math.exp(loss.item())

# Calcula PPL para todas as amostras
print('⏳ Calculando Perplexidade para todas as amostras...')
ppl_scores = []
for s in tqdm(samples, desc='PPL'):
    ppl = compute_perplexity_for_sample(
        finetuned_model, finetuned_tokenizer,
        s['Instruction'], '', s['Output']
    )
    ppl_scores.append(ppl)

mean_ppl = np.mean(ppl_scores)
print(f'\n📊 Perplexidade Média : {mean_ppl:.2f}')
print(f'   Mínima            : {min(ppl_scores):.2f}  (amostra mais fácil)')
print(f'   Máxima            : {max(ppl_scores):.2f}  (amostra mais difícil)')
print(f'\n💡 Interpretação: PPL = {mean_ppl:.1f} significa que, em média,')
print(f'   o modelo considera ~{mean_ppl:.0f} próximas palavras igualmente prováveis.')
# Out:
# ⏳ Calculando Perplexidade para todas as amostras...
# PPL: 100%|██████████| 416/416 [00:52<00:00,  7.93it/s]
# 📊 Perplexidade Média : 3.06
#    Mínima            : 1.26  (amostra mais fácil)
#    Máxima            : 10.41  (amostra mais difícil)
#
# 💡 Interpretação: PPL = 3.1 significa que, em média,
#    o modelo considera ~3 próximas palavras igualmente prováveis.

# %% [markdown]
# ## 6 — Métrica 2: BLEU
#
# ### O que é?
# O **BLEU** (Bilingual Evaluation Understudy) mede a **precisão de n-gramas** entre o texto gerado e uma referência.
#
# $$\text{BLEU} = \text{BP} \cdot \exp\left(\sum_{n=1}^{N} w_n \log p_n\right)$$
#
# onde:
# - $p_n$ = precisão de n-gramas (1-gram, 2-gram, 3-gram, 4-gram)
# - **BP** = Brevity Penalty (penaliza respostas muito curtas)
# - Escala de 0 a 100 (ou 0 a 1)
#
# ### Limitações
# BLEU foca em **precisão** — se todos os n-gramas gerados aparecem na referência. Ele não captura bem paráfrases ou sinônimos.

# %%
# ============================================================
#  MÉTRICA 2 — BLEU
# ============================================================

def compute_bleu(hypotheses: list, references: list) -> dict:
    """
    Calcula BLEU usando sacrebleu.

    Parâmetros
    ----------
    hypotheses : list[str]   — textos gerados pelo modelo
    references : list[str]   — textos de referência (ground truth)

    Retorna
    -------
    dict com score geral e scores por n-grama
    """
    bleu = BLEU(effective_order=True)
    # sacrebleu espera: hyps = list[str], refs = list[list[str]]
    result = bleu.corpus_score(hypotheses, [references])

    return {
        'bleu_score' : result.score,
        '1-gram'     : result.precisions[0],
        '2-gram'     : result.precisions[1],
        '3-gram'     : result.precisions[2],
        '4-gram'     : result.precisions[3],
        'brevity_penalty': result.bp,
    }


# Gera todas as respostas
print('⏳ Gerando respostas do modelo para calcular BLEU...')
generated_responses = []
reference_outputs   = []

for s in tqdm(samples, desc='Gerando'):
    gen = generate_response(
        finetuned_model, finetuned_tokenizer,
        s['Instruction'], '' # Corrigido: 'instruction' para 'Instruction', e 'input' removido
    )
    generated_responses.append(gen)
    reference_outputs.append(s['Output']) # Corrigido: 'output' para 'Output'

bleu_results = compute_bleu(generated_responses, reference_outputs)

print(f'\n📊 Resultados BLEU:')
print(f'   BLEU Score (corpus)  : {bleu_results["bleu_score"]:.2f}')
print(f'   Precisão 1-gram      : {bleu_results["1-gram"]:.2f}%')
print(f'   Precisão 2-gram      : {bleu_results["2-gram"]:.2f}%')
print(f'   Precisão 3-gram      : {bleu_results["3-gram"]:.2f}%')
print(f'   Precisão 4-gram      : {bleu_results["4-gram"]:.2f}%')
print(f'   Brevity Penalty      : {bleu_results["brevity_penalty"]:.4f}')
print(f'\n💡 BLEU > 30 é geralmente considerado bom para geração de texto.')
# Out:
# ⏳ Gerando respostas do modelo para calcular BLEU...
# Gerando:   0%|          | 0/416 [00:00<?, ?it/s][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   0%|          | 1/416 [00:08<1:02:13,  9.00s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   0%|          | 2/416 [00:15<52:54,  7.67s/it]  [transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   1%|          | 3/416 [00:23<52:04,  7.56s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   1%|          | 4/416 [00:26<41:04,  5.98s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   1%|          | 5/416 [00:34<45:08,  6.59s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   1%|▏         | 6/416 [00:48<1:02:48,  9.19s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   2%|▏         | 7/416 [00:54<56:08,  8.24s/it]  [transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   2%|▏         | 8/416 [01:00<49:44,  7.32s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   2%|▏         | 9/416 [01:05<46:11,  6.81s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   2%|▏         | 10/416 [01:10<41:33,  6.14s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   3%|▎         | 11/416 [01:17<43:44,  6.48s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   3%|▎         | 12/416 [01:25<45:46,  6.80s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   3%|▎         | 13/416 [01:31<44:52,  6.68s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   3%|▎         | 14/416 [01:39<46:08,  6.89s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   4%|▎         | 15/416 [01:49<52:58,  7.93s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   4%|▍         | 16/416 [01:55<49:45,  7.46s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   4%|▍         | 17/416 [02:01<45:28,  6.84s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   4%|▍         | 18/416 [02:10<50:57,  7.68s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   5%|▍         | 19/416 [02:21<55:41,  8.42s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   5%|▍         | 20/416 [02:31<1:00:05,  9.11s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   5%|▌         | 21/416 [02:40<59:06,  8.98s/it]  [transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   5%|▌         | 22/416 [02:47<55:47,  8.50s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   6%|▌         | 23/416 [02:50<45:05,  6.88s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   6%|▌         | 24/416 [03:01<52:00,  7.96s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   6%|▌         | 25/416 [03:08<50:50,  7.80s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   6%|▋         | 26/416 [03:17<52:01,  8.00s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   6%|▋         | 27/416 [03:23<47:25,  7.31s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   7%|▋         | 28/416 [03:32<50:37,  7.83s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   7%|▋         | 29/416 [03:42<54:57,  8.52s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   7%|▋         | 30/416 [03:52<58:09,  9.04s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   7%|▋         | 31/416 [04:02<1:00:21,  9.41s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   8%|▊         | 32/416 [04:09<55:22,  8.65s/it]  [transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   8%|▊         | 33/416 [04:22<1:03:39,  9.97s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   8%|▊         | 34/416 [04:45<1:27:16, 13.71s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   8%|▊         | 35/416 [04:54<1:18:45, 12.40s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   9%|▊         | 36/416 [05:03<1:11:54, 11.35s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   9%|▉         | 37/416 [05:07<58:37,  9.28s/it]  [transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   9%|▉         | 38/416 [05:16<57:58,  9.20s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:   9%|▉         | 39/416 [05:25<56:24,  8.98s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  10%|▉         | 40/416 [05:34<56:35,  9.03s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  10%|▉         | 41/416 [05:44<58:40,  9.39s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  10%|█         | 42/416 [05:54<1:00:09,  9.65s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  10%|█         | 43/416 [06:00<53:02,  8.53s/it]  [transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  11%|█         | 44/416 [06:11<56:00,  9.03s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  11%|█         | 45/416 [06:26<1:07:19, 10.89s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  11%|█         | 46/416 [06:31<56:26,  9.15s/it]  [transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  11%|█▏        | 47/416 [06:36<48:38,  7.91s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  12%|█▏        | 48/416 [06:46<52:53,  8.62s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  12%|█▏        | 49/416 [06:55<54:06,  8.85s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  12%|█▏        | 50/416 [07:01<48:46,  8.00s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  12%|█▏        | 51/416 [07:11<51:58,  8.54s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  12%|█▎        | 52/416 [07:21<53:20,  8.79s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  13%|█▎        | 53/416 [07:31<56:08,  9.28s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  13%|█▎        | 54/416 [07:38<52:14,  8.66s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  13%|█▎        | 55/416 [07:45<48:32,  8.07s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  13%|█▎        | 56/416 [07:50<42:41,  7.12s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  14%|█▎        | 57/416 [07:58<43:56,  7.34s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  14%|█▍        | 58/416 [08:05<43:35,  7.31s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  14%|█▍        | 59/416 [08:15<47:48,  8.04s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  14%|█▍        | 60/416 [08:19<41:18,  6.96s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  15%|█▍        | 61/416 [08:24<37:54,  6.41s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  15%|█▍        | 62/416 [08:35<44:37,  7.56s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  15%|█▌        | 63/416 [08:44<48:06,  8.18s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  15%|█▌        | 64/416 [08:49<41:56,  7.15s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  16%|█▌        | 65/416 [08:59<47:13,  8.07s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  16%|█▌        | 66/416 [09:08<48:12,  8.26s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  16%|█▌        | 67/416 [09:16<47:19,  8.14s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  16%|█▋        | 68/416 [09:25<49:51,  8.60s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  17%|█▋        | 69/416 [09:35<52:18,  9.04s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  17%|█▋        | 70/416 [09:45<52:39,  9.13s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  17%|█▋        | 71/416 [09:53<51:10,  8.90s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  17%|█▋        | 72/416 [09:59<45:17,  7.90s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  18%|█▊        | 73/416 [10:06<43:21,  7.58s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  18%|█▊        | 74/416 [10:16<47:24,  8.32s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  18%|█▊        | 75/416 [10:24<46:34,  8.20s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  18%|█▊        | 76/416 [10:34<50:18,  8.88s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  19%|█▊        | 77/416 [10:44<51:31,  9.12s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  19%|█▉        | 78/416 [10:54<53:29,  9.50s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  19%|█▉        | 79/416 [11:04<54:39,  9.73s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  19%|█▉        | 80/416 [11:11<49:31,  8.84s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  19%|█▉        | 81/416 [11:16<42:45,  7.66s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  20%|█▉        | 82/416 [11:25<45:35,  8.19s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  20%|█▉        | 83/416 [11:31<40:51,  7.36s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  20%|██        | 84/416 [11:36<36:58,  6.68s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  20%|██        | 85/416 [11:43<38:18,  6.94s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  21%|██        | 86/416 [11:51<38:35,  7.02s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  21%|██        | 87/416 [12:01<44:22,  8.09s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  21%|██        | 88/416 [12:10<45:08,  8.26s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  21%|██▏       | 89/416 [12:16<40:54,  7.51s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  22%|██▏       | 90/416 [12:26<45:17,  8.34s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  22%|██▏       | 91/416 [12:36<48:22,  8.93s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  22%|██▏       | 92/416 [12:43<44:33,  8.25s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  22%|██▏       | 93/416 [12:53<47:31,  8.83s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  23%|██▎       | 94/416 [12:59<43:15,  8.06s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  23%|██▎       | 95/416 [13:05<39:49,  7.44s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  23%|██▎       | 96/416 [13:15<43:37,  8.18s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  23%|██▎       | 97/416 [13:25<45:51,  8.62s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  24%|██▎       | 98/416 [13:31<42:20,  7.99s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  24%|██▍       | 99/416 [13:41<45:07,  8.54s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  24%|██▍       | 100/416 [13:50<44:46,  8.50s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  24%|██▍       | 101/416 [13:58<44:10,  8.42s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  25%|██▍       | 102/416 [14:03<38:44,  7.40s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  25%|██▍       | 103/416 [14:12<40:45,  7.81s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  25%|██▌       | 104/416 [14:19<39:56,  7.68s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  25%|██▌       | 105/416 [14:26<38:33,  7.44s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  25%|██▌       | 106/416 [14:33<37:26,  7.25s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  26%|██▌       | 107/416 [14:38<34:30,  6.70s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  26%|██▌       | 108/416 [14:43<31:44,  6.18s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  26%|██▌       | 109/416 [14:48<28:53,  5.65s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  26%|██▋       | 110/416 [14:58<35:31,  6.97s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  27%|██▋       | 111/416 [15:06<37:27,  7.37s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  27%|██▋       | 112/416 [15:12<35:18,  6.97s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  27%|██▋       | 113/416 [15:21<37:54,  7.51s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  27%|██▋       | 114/416 [15:27<35:16,  7.01s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  28%|██▊       | 115/416 [15:32<32:44,  6.53s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  28%|██▊       | 116/416 [15:41<37:08,  7.43s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  28%|██▊       | 117/416 [15:51<39:50,  7.99s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  28%|██▊       | 118/416 [15:57<37:20,  7.52s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  29%|██▊       | 119/416 [16:07<40:48,  8.24s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  29%|██▉       | 120/416 [16:13<37:23,  7.58s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  29%|██▉       | 121/416 [16:20<35:57,  7.31s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  29%|██▉       | 122/416 [16:28<37:44,  7.70s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  30%|██▉       | 123/416 [16:39<41:34,  8.51s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  30%|██▉       | 124/416 [16:44<36:34,  7.52s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  30%|███       | 125/416 [16:52<37:11,  7.67s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  30%|███       | 126/416 [16:57<33:25,  6.92s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  31%|███       | 127/416 [17:02<30:23,  6.31s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  31%|███       | 128/416 [17:09<31:41,  6.60s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  31%|███       | 129/416 [17:18<34:35,  7.23s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  31%|███▏      | 130/416 [17:27<36:27,  7.65s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  31%|███▏      | 131/416 [17:36<39:10,  8.25s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  32%|███▏      | 132/416 [17:47<42:03,  8.88s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  32%|███▏      | 133/416 [17:57<43:33,  9.23s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  32%|███▏      | 134/416 [18:06<42:57,  9.14s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  32%|███▏      | 135/416 [18:15<43:36,  9.31s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  33%|███▎      | 136/416 [18:26<45:08,  9.67s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  33%|███▎      | 137/416 [18:30<37:45,  8.12s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  33%|███▎      | 138/416 [18:40<40:02,  8.64s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  33%|███▎      | 139/416 [18:48<38:20,  8.31s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  34%|███▎      | 140/416 [18:54<35:12,  7.66s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  34%|███▍      | 141/416 [19:01<33:56,  7.41s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  34%|███▍      | 142/416 [19:12<38:21,  8.40s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  34%|███▍      | 143/416 [19:22<41:07,  9.04s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  35%|███▍      | 144/416 [19:32<42:21,  9.34s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  35%|███▍      | 145/416 [19:41<41:55,  9.28s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  35%|███▌      | 146/416 [19:48<38:44,  8.61s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  35%|███▌      | 147/416 [19:58<40:06,  8.94s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
# Gerando:  88%|████████▊ | 368/416 [49:00<06:57,  8.69s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  89%|████████▊ | 369/416 [49:10<07:11,  9.18s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  89%|████████▉ | 370/416 [49:20<07:17,  9.50s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  89%|████████▉ | 371/416 [49:27<06:30,  8.68s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  89%|████████▉ | 372/416 [49:37<06:33,  8.93s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  90%|████████▉ | 373/416 [49:44<06:10,  8.62s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  90%|████████▉ | 374/416 [49:50<05:23,  7.71s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  90%|█████████ | 375/416 [49:57<05:09,  7.54s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  90%|█████████ | 376/416 [50:04<04:47,  7.19s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  91%|█████████ | 377/416 [50:14<05:15,  8.09s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  91%|█████████ | 378/416 [50:20<04:46,  7.54s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  91%|█████████ | 379/416 [50:24<04:02,  6.56s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  91%|█████████▏| 380/416 [50:28<03:26,  5.73s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  92%|█████████▏| 381/416 [50:39<04:12,  7.21s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  92%|█████████▏| 382/416 [50:48<04:27,  7.86s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  92%|█████████▏| 383/416 [50:59<04:46,  8.68s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  92%|█████████▏| 384/416 [51:09<04:52,  9.14s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  93%|█████████▎| 385/416 [51:19<04:52,  9.43s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  93%|█████████▎| 386/416 [51:29<04:45,  9.51s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  93%|█████████▎| 387/416 [51:35<04:03,  8.39s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  93%|█████████▎| 388/416 [51:44<04:07,  8.83s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  94%|█████████▎| 389/416 [51:51<03:43,  8.27s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  94%|█████████▍| 390/416 [51:59<03:33,  8.20s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  94%|█████████▍| 391/416 [52:04<02:56,  7.05s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  94%|█████████▍| 392/416 [52:14<03:14,  8.10s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  94%|█████████▍| 393/416 [52:21<02:56,  7.66s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  95%|█████████▍| 394/416 [52:32<03:08,  8.57s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  95%|█████████▍| 395/416 [52:42<03:13,  9.19s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  95%|█████████▌| 396/416 [52:49<02:46,  8.34s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  95%|█████████▌| 397/416 [52:56<02:33,  8.10s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  96%|█████████▌| 398/416 [53:06<02:36,  8.70s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  96%|█████████▌| 399/416 [53:14<02:23,  8.41s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  96%|█████████▌| 400/416 [53:17<01:47,  6.72s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  96%|█████████▋| 401/416 [53:23<01:39,  6.65s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  97%|█████████▋| 402/416 [53:33<01:46,  7.64s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  97%|█████████▋| 403/416 [53:41<01:38,  7.61s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  97%|█████████▋| 404/416 [53:46<01:24,  7.03s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  97%|█████████▋| 405/416 [53:54<01:20,  7.35s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  98%|█████████▊| 406/416 [54:05<01:22,  8.27s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  98%|█████████▊| 407/416 [54:11<01:08,  7.61s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  98%|█████████▊| 408/416 [54:18<00:59,  7.42s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  98%|█████████▊| 409/416 [54:28<00:57,  8.24s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  99%|█████████▊| 410/416 [54:37<00:51,  8.56s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  99%|█████████▉| 411/416 [54:46<00:42,  8.45s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  99%|█████████▉| 412/416 [54:56<00:35,  8.92s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando:  99%|█████████▉| 413/416 [55:05<00:26,  8.98s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando: 100%|█████████▉| 414/416 [55:13<00:17,  8.77s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando: 100%|█████████▉| 415/416 [55:19<00:08,  8.06s/it][transformers] Both `max_new_tokens` (=200) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gerando: 100%|██████████| 416/416 [55:27<00:00,  8.00s/it]
# 📊 Resultados BLEU:
#    BLEU Score (corpus)  : 8.93
#    Precisão 1-gram      : 22.05%
#    Precisão 2-gram      : 9.71%
#    Precisão 3-gram      : 6.43%
#    Precisão 4-gram      : 4.62%
#    Brevity Penalty      : 1.0000
#
# 💡 BLEU > 30 é geralmente considerado bom para geração de texto.

# %% [markdown]
# ## 7 — Métrica 3: ROUGE
#
# ### O que é?
# **ROUGE** (Recall-Oriented Understudy for Gisting Evaluation) complementa o BLEU focando no **recall** — quanta informação da referência aparece na resposta gerada.
#
# | Variante | O que mede |
# |---|---|
# | **ROUGE-1** | Sobreposição de unigramas (palavras individuais) |
# | **ROUGE-2** | Sobreposição de bigramas (pares de palavras) |
# | **ROUGE-L** | Subsequência Comum mais Longa (LCS) — captura ordem |
#
# Cada métrica retorna **Precisão**, **Recall** e **F1** (harmônica entre os dois).

# %%
# ============================================================
#  MÉTRICA 3 — ROUGE
# ============================================================

def compute_rouge_scores(hypotheses: list, references: list) -> pd.DataFrame:
    """
    Calcula ROUGE-1, ROUGE-2 e ROUGE-L para cada par (gerado, referência).

    Retorna um DataFrame com Precision, Recall e F1 para cada variante.
    """
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    records = []

    for hyp, ref in zip(hypotheses, references):
        scores = scorer.score(ref, hyp)
        records.append({
            'ROUGE-1 P' : scores['rouge1'].precision,
            'ROUGE-1 R' : scores['rouge1'].recall,
            'ROUGE-1 F1': scores['rouge1'].fmeasure,
            'ROUGE-2 P' : scores['rouge2'].precision,
            'ROUGE-2 R' : scores['rouge2'].recall,
            'ROUGE-2 F1': scores['rouge2'].fmeasure,
            'ROUGE-L P' : scores['rougeL'].precision,
            'ROUGE-L R' : scores['rougeL'].recall,
            'ROUGE-L F1': scores['rougeL'].fmeasure,
        })

    return pd.DataFrame(records)


df_rouge = compute_rouge_scores(generated_responses, reference_outputs)

print('📊 Médias ROUGE (todas as amostras):\n')
rouge_means = df_rouge.mean()

for variant in ['ROUGE-1', 'ROUGE-2', 'ROUGE-L']:
    p  = rouge_means[f'{variant} P']
    r  = rouge_means[f'{variant} R']
    f1 = rouge_means[f'{variant} F1']
    print(f'   {variant:<8}  Precision={p:.3f}  Recall={r:.3f}  F1={f1:.3f}')

print(f'\n💡 ROUGE-L F1 alto indica que o modelo mantém a ordem e estrutura do texto de referência.')
# Out:
# 📊 Médias ROUGE (todas as amostras):
#
#    ROUGE-1   Precision=0.246  Recall=0.515  F1=0.320
#    ROUGE-2   Precision=0.128  Recall=0.273  F1=0.166
#    ROUGE-L   Precision=0.200  Recall=0.424  F1=0.260
#
# 💡 ROUGE-L F1 alto indica que o modelo mantém a ordem e estrutura do texto de referência.

# %% [markdown]
# ## 8 — Métrica 4: Fidelidade (Faithfulness)
#
# ### O que é?
# A **Fidelidade** avalia se a resposta gerada é **factualmente consistente** com o contexto de entrada (instruction + input). É crítica em sistemas **RAG** (Retrieval-Augmented Generation).
#
# ### Como é calculada aqui?
# Usamos uma abordagem léxica baseada em **sobreposição de tokens importantes**:
# 1. Extraímos tokens significativos do contexto (substantivos, números, marcas)
# 2. Calculamos a fração presente na resposta gerada
#
# > ⚠️ **Nota:** Em produção, Faithfulness é melhor avaliada por um modelo de NLI (Natural Language Inference) como DeBERTa ou via LLM-as-judge.

# %%
# ============================================================
#  MÉTRICA 4 — FIDELIDADE (FAITHFULNESS)
# ============================================================

def extract_key_tokens(text: str) -> set:
    """
    Extrai tokens relevantes: números, palavras com maiúscula inicial
    (marcas, modelos), e tokens longos (substantivos específicos).
    Ignora stopwords em português e tokens muito curtos.
    """
    # Stopwords comuns em português
    STOPWORDS = {
        'de', 'a', 'o', 'que', 'e', 'do', 'da', 'em', 'um', 'para', 'é',
        'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as',
        'dos', 'como', 'mas', 'foi', 'ao', 'ele', 'das', 'tem', 'à', 'seu',
        'sua', 'ou', 'ser', 'quando', 'muito', 'há', 'nos', 'já', 'está',
        'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre',
        'era', 'depois', 'sem', 'mesmo', 'aos', 'ter', 'seus', 'quem',
        'nas', 'me', 'esse', 'eles', 'estão', 'você', 'tinha', 'foram',
        'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'têm', 'numa'
    }

    # Extrai palavras e números mantendo a diferenciação de maiúsculas
    tokens = re.findall(r'[A-Za-zÀ-ÖØ-öø-ÿ0-9]+', text)

    return {
        t for t in tokens
        if (t.isdigit() or len(t) >= 4) and t.lower() not in STOPWORDS
    }


def compute_faithfulness(instruction: str, input_text: str, generated: str) -> float:
    """
    Calcula a Fidelidade como a proporção de tokens-chave do contexto
    (instruction + input) que aparece na resposta gerada.

    Score = |tokens_contexto ∩ tokens_gerado| / |tokens_contexto|

    Retorna 0.5 (neutro) se não houver tokens-chave no contexto.
    """
    context_tokens   = extract_key_tokens(instruction + ' ' + input_text)
    generated_tokens = extract_key_tokens(generated)

    if not context_tokens:
        return 0.5  # sem contexto mensurável, score neutro

    overlap = context_tokens & generated_tokens
    return len(overlap) / len(context_tokens)


faithfulness_scores = []
for s, gen in zip(samples, generated_responses):
    score = compute_faithfulness(s['Instruction'], '', gen) # Corrigido: 'instruction' para 'Instruction', 'input' removido
    faithfulness_scores.append(score)

mean_faith = np.mean(faithfulness_scores)
print(f'📊 Fidelidade (Faithfulness):')
print(f'   Média  : {mean_faith:.3f}')
print(f'   Mínima : {min(faithfulness_scores):.3f}')
print(f'   Máxima : {max(faithfulness_scores):.3f}')
print(f'\n💡 Score próximo de 1.0 indica que a resposta cita informações do contexto fornecido.')
print(f'   Crítico em sistemas RAG onde o modelo deve se basear nos documentos recuperados.')
# Out:
# 📊 Fidelidade (Faithfulness):
#    Média  : 0.771
#    Mínima : 0.000
#    Máxima : 1.000
#
# 💡 Score próximo de 1.0 indica que a resposta cita informações do contexto fornecido.
#    Crítico em sistemas RAG onde o modelo deve se basear nos documentos recuperados.

# %% [markdown]
# ## 9 — Métrica 5: Relevância da Resposta (Answer Relevance)
#
# ### O que é?
# A **Relevância** mede se a resposta realmente **responde à pergunta feita**. Uma resposta pode ser fluente e fiel ao contexto, mas não responder à instrução específica.
#
# ### Como é calculada aqui?
# Usamos **Jaccard Similarity** sobre tokens-chave entre a instrução e a resposta gerada:
#
# $$\text{Relevância} = \frac{|\text{tokens}_{\text{instrução}} \cap \text{tokens}_{\text{resposta}}|}{|\text{tokens}_{\text{instrução}} \cup \text{tokens}_{\text{resposta}}|}$$
#
# > ⚠️ Em produção, use embeddings semânticos (sentence-transformers) ou LLM-as-judge para maior precisão.

# %%
# ============================================================
#  MÉTRICA 5 — RELEVÂNCIA DA RESPOSTA (ANSWER RELEVANCE)
# ============================================================

def compute_answer_relevance(instruction: str, generated: str) -> float:
    """
    Calcula a Relevância como Jaccard Similarity entre os tokens-chave
    da instrução e da resposta gerada.

    Jaccard = |A ∩ B| / |A ∪ B|

    Um score alto indica que a resposta usa vocabulário ligado à pergunta.
    """
    instr_tokens = extract_key_tokens(instruction)
    gen_tokens   = extract_key_tokens(generated)

    if not instr_tokens and not gen_tokens:
        return 0.5

    intersection = instr_tokens & gen_tokens
    union         = instr_tokens | gen_tokens

    # Jaccard puro penaliza respostas muito longas — adicionamos bônus
    # de cobertura da instrução para valorizar completude
    jaccard  = len(intersection) / len(union)
    coverage = len(intersection) / len(instr_tokens) if instr_tokens else 0

    return (jaccard + coverage) / 2.0


relevance_scores = [
    compute_answer_relevance(s['Instruction'], gen) # Corrigido: 'instruction' para 'Instruction'
    for s, gen in zip(samples, generated_responses)
]

mean_rel = np.mean(relevance_scores)
print(f'📊 Relevância da Resposta:')
print(f'   Média  : {mean_rel:.3f}')
print(f'   Mínima : {min(relevance_scores):.3f}')
print(f'   Máxima : {max(relevance_scores):.3f}')
print(f'\n💡 Score alto = resposta usa o vocabulário da pergunta e cobre seus aspectos principais.')
# Out:
# 📊 Relevância da Resposta:
#    Média  : 0.480
#    Mínima : 0.000
#    Máxima : 0.867
#
# 💡 Score alto = resposta usa o vocabulário da pergunta e cobre seus aspectos principais.

# %% [markdown]
# ## 10 — Métrica 6: Aderência ao Plano (Plan Adherence)
#
# ### O que é?
# A **Aderência ao Plano** mede se o agente de IA segue a estrutura esperada de resposta — relevante em contextos de **AI Agents** que devem seguir planos de ação predefinidos.
#
# ### Como é calculada aqui?
# Para nosso dataset automotivo, o "plano" esperado é a estrutura do output de referência:
# - ✅ Numeração de passos (`1. 2. 3.`)
# - ✅ Uso de bullet points (`-`, `•`)
# - ✅ Formato de valores técnicos (ex.: `35 psi`, `10,000 miles`)
# - ✅ Presença de seções com dois-pontos
#
# Avaliamos se a resposta gerada segue os mesmos **elementos estruturais** que a referência.

# %%
# ============================================================
#  MÉTRICA 6 — ADERÊNCIA AO PLANO (PLAN ADHERENCE)
# ============================================================

def detect_structural_elements(text: str) -> dict:
    """
    Detecta elementos estruturais no texto:
    - has_numbered_list : tem lista numerada (1. 2. ...)
    - has_bullets       : tem bullet points (- ou •)
    - has_technical     : tem valores técnicos (números + unidade)
    - has_sections      : tem seções com dois-pontos no início de linha
    - step_count        : número de passos numerados
    """
    return {
        'has_numbered_list': bool(re.search(r'^\d+\.\s', text, re.MULTILINE)),
        'has_bullets'      : bool(re.search(r'^[\-•]\s', text, re.MULTILINE)),
        'has_technical'    : bool(re.search(
            #r'\d+[,.]?\d*\s*(psi|mph|lbs|miles|km|liter|L|V\d|octane|months?)',
            r'\d+[,.]?\d*\s*(psi|rpm|km|km/h|kW|CV|litros?|L|meses?|anos?|horas?)',
            text, re.IGNORECASE
        )),
        'has_sections'     : bool(re.search(r'^[A-Z][^\n]+:\s*$', text, re.MULTILINE)),
        'step_count'       : len(re.findall(r'^\d+\.\s', text, re.MULTILINE)),
    }


def compute_plan_adherence(reference: str, generated: str) -> float:
    """
    Calcula a Aderência ao Plano comparando os elementos estruturais
    do texto de referência com os da resposta gerada.

    Para cada elemento estrutural presente na referência, verifica
    se também está presente na resposta gerada.

    Retorna a proporção de elementos seguidos corretamente.
    """
    ref_struct = detect_structural_elements(reference)
    gen_struct = detect_structural_elements(generated)

    checks = []
    binary_features = ['has_numbered_list', 'has_bullets', 'has_technical', 'has_sections']

    for feat in binary_features:
        if ref_struct[feat]:  # Só avalia se a referência tem esse elemento
            checks.append(1.0 if gen_struct[feat] else 0.0)

    # Verifica se contagem de passos é similar (±1)
    if ref_struct['step_count'] > 0:
        step_ratio = min(gen_struct['step_count'], ref_struct['step_count']) / \
                     max(gen_struct['step_count'], ref_struct['step_count'], 1)
        checks.append(step_ratio)

    return np.mean(checks) if checks else 0.5


plan_scores = [
    compute_plan_adherence(s['Output'], gen) # Corrigido: 'output' para 'Output'
    for s, gen in zip(samples, generated_responses)
]

mean_plan = np.mean(plan_scores)
print(f'📊 Aderência ao Plano (Plan Adherence):')
print(f'   Média  : {mean_plan:.3f}')
print(f'   Mínima : {min(plan_scores):.3f}')
print(f'   Máxima : {max(plan_scores):.3f}')
print(f'\n💡 Score alto indica que o modelo segue a mesma estrutura de resposta da referência:')
print(f'   listas numeradas, bullets, valores técnicos e organização em seções.')
# Out:
# 📊 Aderência ao Plano (Plan Adherence):
#    Média  : 0.493
#    Mínima : 0.000
#    Máxima : 1.000
#
# 💡 Score alto indica que o modelo segue a mesma estrutura de resposta da referência:
#    listas numeradas, bullets, valores técnicos e organização em seções.

# %% [markdown]
# ## 📋 Célula 12 — Tabela Consolidada de Resultados
#
# Unificamos todos os scores por amostra em um único DataFrame para análise comparativa.

# %%
# ============================================================
#  TABELA CONSOLIDADA DE RESULTADOS
# ============================================================

rouge_f1_1 = df_rouge['ROUGE-1 F1'].tolist()
rouge_f1_2 = df_rouge['ROUGE-2 F1'].tolist()
rouge_f1_L = df_rouge['ROUGE-L F1'].tolist()

# BLEU por amostra (sacrebleu sentence-level)
bleu_metric = BLEU(effective_order=True)
bleu_per_sample = [
    bleu_metric.sentence_score(hyp, [ref]).score
    for hyp, ref in zip(generated_responses, reference_outputs)
]

df_results = pd.DataFrame({
    'Instrução'           : [s['Instruction'][:50] + '...' for s in samples],
    'PPL'                 : [round(p, 2) for p in ppl_scores],
    'BLEU'                : [round(b, 2) for b in bleu_per_sample],
    'ROUGE-1 F1'          : [round(r, 3) for r in rouge_f1_1],
    'ROUGE-2 F1'          : [round(r, 3) for r in rouge_f1_2],
    'ROUGE-L F1'          : [round(r, 3) for r in rouge_f1_L],
    'Faithfulness'        : [round(f, 3) for f in faithfulness_scores],
    'Answer Relevance'    : [round(r, 3) for r in relevance_scores],
    'Plan Adherence'      : [round(p, 3) for p in plan_scores],
})

# Linha de médias
means_row = pd.DataFrame({
    'Instrução'        : '📊 MÉDIA',
    'PPL'              : round(np.mean(ppl_scores), 2),
    'BLEU'             : round(np.mean(bleu_per_sample), 2),
    'ROUGE-1 F1'       : round(np.mean(rouge_f1_1), 3),
    'ROUGE-2 F1'       : round(np.mean(rouge_f1_2), 3),
    'ROUGE-L F1'       : round(np.mean(rouge_f1_L), 3),
    'Faithfulness'     : round(np.mean(faithfulness_scores), 3),
    'Answer Relevance' : round(np.mean(relevance_scores), 3),
    'Plan Adherence'   : round(np.mean(plan_scores), 3),
}, index=[0]) # Adicionando index=[0] aqui para resolver o ValueError

df_display = pd.concat([df_results, means_row], ignore_index=True)

def highlight_mean_row(row):
    if row['Instrução'] == '📊 MÉDIA':
        return ['background-color: #1a1a2e; color: #e0e0e0; font-weight: bold'] * len(row)
    return [''] * len(row)

styled = (
    df_display.style
    .apply(highlight_mean_row, axis=1)
    .background_gradient(subset=['ROUGE-1 F1', 'ROUGE-2 F1', 'ROUGE-L F1',
                                  'Faithfulness', 'Answer Relevance', 'Plan Adherence'],
                         cmap='YlGn', vmin=0, vmax=1)
    .background_gradient(subset=['PPL'], cmap='YlOrRd_r')
    .set_caption('📋 Resultados por Amostra — Todas as Métricas')
)

styled
# Out:
# <style type="text/css">
# #T_2282e_row0_col1, #T_2282e_row10_col1, #T_2282e_row93_col1, #T_2282e_row284_col1 {
#   background-color: #e1191d;
#   color: #f1f1f1;
# }
# #T_2282e_row0_col3, #T_2282e_row64_col7, #T_2282e_row112_col3, #T_2282e_row127_col3, #T_2282e_row129_col7, #T_2282e_row209_col5, #T_2282e_row247_col5, #T_2282e_row264_col5, #T_2282e_row306_col5, #T_2282e_row340_col5, #T_2282e_row366_col3, #T_2282e_row373_col3, #T_2282e_row383_col5 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_2282e_row0_col4, #T_2282e_row81_col4, #T_2282e_row99_col4, #T_2282e_row118_col4, #T_2282e_row122_col5, #T_2282e_row157_col4, #T_2282e_row210_col4, #T_2282e_row226_col4, #T_2282e_row235_col5, #T_2282e_row248_col3, #T_2282e_row248_col5, #T_2282e_row302_col4, #T_2282e_row320_col4, #T_2282e_row322_col3, #T_2282e_row322_col5, #T_2282e_row387_col4, #T_2282e_row404_col5 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_2282e_row0_col5, #T_2282e_row8_col5, #T_2282e_row20_col3, #T_2282e_row20_col6, #T_2282e_row43_col3, #T_2282e_row45_col5, #T_2282e_row46_col3, #T_2282e_row86_col6, #T_2282e_row91_col5, #T_2282e_row92_col6, #T_2282e_row93_col3, #T_2282e_row97_col5, #T_2282e_row102_col6, #T_2282e_row141_col5, #T_2282e_row158_col5, #T_2282e_row165_col3, #T_2282e_row170_col4, #T_2282e_row173_col3, #T_2282e_row180_col5, #T_2282e_row184_col5, #T_2282e_row200_col5, #T_2282e_row219_col5, #T_2282e_row245_col4, #T_2282e_row256_col4, #T_2282e_row273_col5, #T_2282e_row279_col3, #T_2282e_row288_col4, #T_2282e_row294_col5, #T_2282e_row312_col6, #T_2282e_row333_col3, #T_2282e_row350_col5, #T_2282e_row384_col3, #T_2282e_row385_col3, #T_2282e_row385_col5 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_2282e_row0_col6, #T_2282e_row34_col3, #T_2282e_row46_col7, #T_2282e_row90_col6, #T_2282e_row101_col3, #T_2282e_row115_col7, #T_2282e_row166_col7, #T_2282e_row192_col7, #T_2282e_row212_col3, #T_2282e_row239_col3 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_2282e_row0_col7, #T_2282e_row16_col3, #T_2282e_row34_col4, #T_2282e_row79_col5, #T_2282e_row85_col5, #T_2282e_row105_col5, #T_2282e_row164_col5, #T_2282e_row231_col3, #T_2282e_row240_col4, #T_2282e_row269_col3, #T_2282e_row289_col3, #T_2282e_row315_col5, #T_2282e_row357_col5, #T_2282e_row366_col5 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_2282e_row0_col8, #T_2282e_row1_col8, #T_2282e_row2_col8, #T_2282e_row3_col8, #T_2282e_row4_col8, #T_2282e_row5_col8, #T_2282e_row6_col6, #T_2282e_row6_col8, #T_2282e_row7_col6, #T_2282e_row7_col8, #T_2282e_row8_col8, #T_2282e_row9_col8, #T_2282e_row10_col7, #T_2282e_row10_col8, #T_2282e_row11_col8, #T_2282e_row12_col8, #T_2282e_row13_col8, #T_2282e_row14_col6, #T_2282e_row14_col8, #T_2282e_row15_col8, #T_2282e_row16_col8, #T_2282e_row17_col8, #T_2282e_row18_col8, #T_2282e_row19_col8, #T_2282e_row20_col8, #T_2282e_row21_col8, #T_2282e_row22_col6, #T_2282e_row22_col8, #T_2282e_row23_col8, #T_2282e_row24_col8, #T_2282e_row25_col8, #T_2282e_row26_col8, #T_2282e_row27_col8, #T_2282e_row28_col8, #T_2282e_row29_col8, #T_2282e_row30_col8, #T_2282e_row31_col8, #T_2282e_row32_col8, #T_2282e_row33_col8, #T_2282e_row34_col8, #T_2282e_row35_col8, #T_2282e_row36_col8, #T_2282e_row37_col8, #T_2282e_row38_col8, #T_2282e_row39_col8, #T_2282e_row40_col8, #T_2282e_row41_col8, #T_2282e_row42_col8, #T_2282e_row43_col8, #T_2282e_row44_col8, #T_2282e_row45_col8, #T_2282e_row46_col8, #T_2282e_row47_col8, #T_2282e_row48_col8, #T_2282e_row49_col8, #T_2282e_row50_col8, #T_2282e_row51_col8, #T_2282e_row52_col8, #T_2282e_row53_col8, #T_2282e_row54_col8, #T_2282e_row55_col8, #T_2282e_row56_col8, #T_2282e_row57_col8, #T_2282e_row58_col8, #T_2282e_row59_col8, #T_2282e_row60_col8, #T_2282e_row61_col8, #T_2282e_row62_col8, #T_2282e_row63_col8, #T_2282e_row65_col8, #T_2282e_row66_col8, #T_2282e_row67_col8, #T_2282e_row69_col8, #T_2282e_row70_col6, #T_2282e_row70_col8, #T_2282e_row71_col8, #T_2282e_row72_col8, #T_2282e_row73_col8, #T_2282e_row74_col8, #T_2282e_row75_col8, #T_2282e_row76_col8, #T_2282e_row77_col8, #T_2282e_row78_col8, #T_2282e_row79_col8, #T_2282e_row80_col8, #T_2282e_row81_col8, #T_2282e_row82_col8, #T_2282e_row83_col8, #T_2282e_row84_col8, #T_2282e_row85_col8, #T_2282e_row86_col8, #T_2282e_row87_col8, #T_2282e_row88_col8, #T_2282e_row89_col8, #T_2282e_row90_col8, #T_2282e_row91_col8, #T_2282e_row92_col8, #T_2282e_row93_col8, #T_2282e_row94_col8, #T_2282e_row95_col8, #T_2282e_row96_col6, #T_2282e_row96_col8, #T_2282e_row97_col8, #T_2282e_row98_col8, #T_2282e_row99_col8, #T_2282e_row100_col8, #T_2282e_row101_col8, #T_2282e_row102_col8, #T_2282e_row103_col8, #T_2282e_row104_col8, #T_2282e_row105_col8, #T_2282e_row106_col8, #T_2282e_row107_col8, #T_2282e_row108_col8, #T_2282e_row109_col7, #T_2282e_row109_col8, #T_2282e_row110_col8, #T_2282e_row111_col8, #T_2282e_row112_col8, #T_2282e_row113_col8, #T_2282e_row114_col8, #T_2282e_row115_col8, #T_2282e_row116_col8, #T_2282e_row117_col8, #T_2282e_row118_col8, #T_2282e_row119_col8, #T_2282e_row120_col8, #T_2282e_row121_col8, #T_2282e_row122_col8, #T_2282e_row123_col8, #T_2282e_row124_col8, #T_2282e_row125_col8, #T_2282e_row126_col8, #T_2282e_row127_col8, #T_2282e_row128_col8, #T_2282e_row129_col6, #T_2282e_row129_col8, #T_2282e_row130_col8, #T_2282e_row131_col8, #T_2282e_row132_col8, #T_2282e_row133_col8, #T_2282e_row134_col8, #T_2282e_row135_col8, #T_2282e_row136_col8, #T_2282e_row137_col8, #T_2282e_row138_col8, #T_2282e_row139_col8, #T_2282e_row140_col8, #T_2282e_row141_col8, #T_2282e_row142_col8, #T_2282e_row143_col8, #T_2282e_row144_col8, #T_2282e_row145_col8, #T_2282e_row146_col8, #T_2282e_row147_col8, #T_2282e_row149_col8, #T_2282e_row150_col8, #T_2282e_row151_col8, #T_2282e_row152_col8, #T_2282e_row154_col8, #T_2282e_row155_col8, #T_2282e_row156_col8, #T_2282e_row157_col8, #T_2282e_row158_col8, #T_2282e_row159_col8, #T_2282e_row160_col8, #T_2282e_row161_col8, #T_2282e_row162_col8, #T_2282e_row163_col8, #T_2282e_row164_col8, #T_2282e_row165_col8, #T_2282e_row166_col8, #T_2282e_row167_col8, #T_2282e_row168_col8, #T_2282e_row169_col7, #T_2282e_row169_col8, #T_2282e_row170_col8, #T_2282e_row171_col8, #T_2282e_row172_col8, #T_2282e_row173_col8, #T_2282e_row174_col8, #T_2282e_row175_col8, #T_2282e_row176_col8, #T_2282e_row177_col8, #T_2282e_row178_col8, #T_2282e_row180_col8, #T_2282e_row181_col8, #T_ ...

# %% [markdown]
# ## 📈 Célula 13 — Visualizações
#
# Gráficos que facilitam a interpretação dos resultados.

# %%
# ============================================================
#  VISUALIZAÇÕES
# ============================================================

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('📊 Avaliação do Modelo Fine-Tuned — Visão Geral', fontsize=16, fontweight='bold', y=1.01)

sample_labels = [f'S{i+1}' for i in range(len(samples))]
colors = plt.cm.Set2.colors

# --- 1. Perplexidade por Amostra ---
ax = axes[0, 0]
bars = ax.bar(sample_labels, ppl_scores, color=colors[0], edgecolor='white', linewidth=0.5)
ax.axhline(np.mean(ppl_scores), color='red', linestyle='--', linewidth=1.5, label=f'Média: {np.mean(ppl_scores):.1f}')
ax.set_title('Perplexidade (PPL)', fontweight='bold')
ax.set_ylabel('PPL (menor = melhor)')
ax.set_xlabel('Amostra')
ax.legend(fontsize=9)

# --- 2. BLEU por Amostra ---
ax = axes[0, 1]
ax.bar(sample_labels, bleu_per_sample, color=colors[1], edgecolor='white', linewidth=0.5)
ax.axhline(np.mean(bleu_per_sample), color='red', linestyle='--', linewidth=1.5,
           label=f'Média: {np.mean(bleu_per_sample):.1f}')
ax.set_title('BLEU Score por Amostra', fontweight='bold')
ax.set_ylabel('BLEU (maior = melhor)')
ax.set_xlabel('Amostra')
ax.legend(fontsize=9)

# --- 3. ROUGE F1 Comparativo ---
ax = axes[0, 2]
x = np.arange(len(sample_labels))
w = 0.28
ax.bar(x - w, rouge_f1_1, w, label='ROUGE-1', color=colors[2], edgecolor='white')
ax.bar(x,     rouge_f1_2, w, label='ROUGE-2', color=colors[3], edgecolor='white')
ax.bar(x + w, rouge_f1_L, w, label='ROUGE-L', color=colors[4], edgecolor='white')
ax.set_title('ROUGE F1 por Amostra', fontweight='bold')
ax.set_ylabel('F1 Score')
ax.set_xlabel('Amostra')
ax.set_xticks(x)
ax.set_xticklabels(sample_labels)
ax.legend(fontsize=9)

# --- 4. Faithfulness, Relevance, Plan Adherence ---
ax = axes[1, 0]
ax.plot(sample_labels, faithfulness_scores, 'o-', color=colors[0], label='Faithfulness', linewidth=2)
ax.plot(sample_labels, relevance_scores, 's-', color=colors[1], label='Answer Relevance', linewidth=2)
ax.plot(sample_labels, plan_scores, '^-', color=colors[2], label='Plan Adherence', linewidth=2)
ax.set_ylim(0, 1.05)
ax.set_title('Métricas de Qualidade por Amostra', fontweight='bold')
ax.set_ylabel('Score (0–1)')
ax.set_xlabel('Amostra')
ax.legend(fontsize=9)

# --- 5. Radar / Spider Chart das Médias ---
ax = axes[1, 1]
ax.remove()
ax_radar = fig.add_subplot(2, 3, 5, projection='polar')

metric_names  = ['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'Faithful', 'Relevance', 'Plan']
metric_values = [
    np.mean(rouge_f1_1),
    np.mean(rouge_f1_2),
    np.mean(rouge_f1_L),
    np.mean(faithfulness_scores),
    np.mean(relevance_scores),
    np.mean(plan_scores),
]

angles = np.linspace(0, 2 * np.pi, len(metric_names), endpoint=False).tolist()
values_closed = metric_values + [metric_values[0]]
angles_closed = angles + [angles[0]]

ax_radar.plot(angles_closed, values_closed, 'o-', linewidth=2, color=colors[3])
ax_radar.fill(angles_closed, values_closed, alpha=0.25, color=colors[3])
ax_radar.set_xticks(angles)
ax_radar.set_xticklabels(metric_names, size=9)
ax_radar.set_ylim(0, 1)
ax_radar.set_title('Radar das Médias (0–1)', fontweight='bold', pad=15)

# --- 6. Sumário em barras horizontais ---
ax = axes[1, 2]
summary_names = [
    'ROUGE-1 F1', 'ROUGE-2 F1', 'ROUGE-L F1',
    'Faithfulness', 'Answer Relevance', 'Plan Adherence'
]
summary_vals = metric_values
bar_colors   = [colors[i % len(colors)] for i in range(len(summary_names))]
h_bars = ax.barh(summary_names, summary_vals, color=bar_colors, edgecolor='white')
ax.set_xlim(0, 1)
ax.set_title('Resumo das Métricas (Médias)', fontweight='bold')
ax.set_xlabel('Score médio')
for bar, val in zip(h_bars, summary_vals):
    ax.text(val + 0.01, bar.get_y() + bar.get_height() / 2,
            f'{val:.3f}', va='center', fontsize=9)

plt.tight_layout()
plt.savefig('avaliacao_metricas.png', dpi=150, bbox_inches='tight')
plt.show()
print('✅ Figura salva em avaliacao_metricas.png')
# Out:
# ✅ Figura salva em avaliacao_metricas.png

# %% [markdown]
# ## 🔬 Célula 14 — Análise Qualitativa: Comparação Resposta vs. Referência
#
# Examinamos lado a lado as respostas geradas vs. as esperadas para 3 amostras selecionadas.

# %%
# ============================================================
#  ANÁLISE QUALITATIVA
# ============================================================

INSPECT_INDICES = [0, 3, 6]   # Altere para ver outras amostras

for idx in INSPECT_INDICES:
    s   = samples[idx]
    gen = generated_responses[idx]

    print('=' * 70)
    print(f'🔎 AMOSTRA {idx + 1}')
    print(f'📌 Instrução : {s["Instruction"]}')
    # Removido: 'input' não existe mais nos dados
    # if s['input']:
    #     print(f'📥 Contexto  : {s["input"]}')
    print()
    print('✅ REFERÊNCIA:')
    print(s["Output"])
    print()
    print('🤖 GERADO:')
    print(gen if gen else '[sem saída gerada]')
    print()
    print(f'   PPL              = {ppl_scores[idx]:.2f}')
    print(f'   BLEU             = {bleu_per_sample[idx]:.2f}')
    print(f'   ROUGE-L F1       = {rouge_f1_L[idx]:.3f}')
    print(f'   Faithfulness     = {faithfulness_scores[idx]:.3f}')
    print(f'   Answer Relevance = {relevance_scores[idx]:.3f}')
    print(f'   Plan Adherence   = {plan_scores[idx]:.3f}')
    print()
# Out:
# ======================================================================
# 🔎 AMOSTRA 1
# 📌 Instrução : Qual é a principal característica técnica abordada no manual para sistemas de comandos de segurança?
#
# ✅ REFERÊNCIA:
# O manual aborda principalmente as características técnicas necessárias para o projeto e instalação de sistemas de comandos de segurança em máquinas e equipamentos, enfocando tanto sistemas simples quanto redundantes com dois canais, conforme a Norma Regulamentadora nº 12 (NR-12).
#
# 🤖 GERADO:
# O manual aborda técnicas para a comprovação da capacidade de parada em sistemas de comandos de segurança, incluindo a detecção de falhas em dispositivos de intertravamento com bloqueio e a monitoração de falhas em dispositivos de comando de intertravamento simples. Além disso, é descrito como manter os dispositivos de comando de intertravamento em estado de comando para garantir segurança.
#
# N.B.: Este exemplo demonstra que o texto do manual, quando analizado em conjunto com a fonte citada na ABNT NBR ISO 14119:2021, proporciona um conhecimento suficiente para a comprovação de sistemas de comando de segurança.
#
#    PPL              = 3.48
#    BLEU             = 5.87
#    ROUGE-L F1       = 0.253
#    Faithfulness     = 0.444
#    Answer Relevance = 0.269
#    Plan Adherence   = 0.500
#
# ======================================================================
# 🔎 AMOSTRA 4
# 📌 Instrução : Qual é o objetivo principal da revisão mencionada no manual?
#
# ✅ REFERÊNCIA:
# O objetivo principal da revisão foi permitir a aplicação de várias tecnologias em máquinas e equipamentos, desde que atendam aos requisitos definidos no item 12.4.14 da NR-12.
#
# 🤖 GERADO:
# A revisão tem como objetivo melhorar a qualidade da produção em relação ao desempenho do dispositivo, garantindo a confiabilidade e a estabilidade do sistema, com a garantia de segurança e proteção contra falhas mecânicas.
#
#    PPL              = 4.27
#    BLEU             = 1.73
#    ROUGE-L F1       = 0.189
#    Faithfulness     = 0.333
#    Answer Relevance = 0.212
#    Plan Adherence   = 0.500
#
# ======================================================================
# 🔎 AMOSTRA 7
# 📌 Instrução : Qual processo de avaliação de riscos é precedido pela redução de riscos, segundo NR-12?
#
# ✅ REFERÊNCIA:
# De acordo com NR-12, a apreciação de riscos é precedida pela redução de riscos, sendo esses processos distintos, apesar de sequenciais. Após a apreciação, se necessário, é preciso implementar medidas de projeto inerentemente seguras, seguidas por medidas de segurança e proteção complementares.
#
# 🤖 GERADO:
# Na NR-12, a avaliação de riscos é precedida pela redução de riscos, mas não há especificação sobre o tipo de avaliação necessária, como o uso de um sistema de avaliação de riscos. No entanto, a NR-12 enfatiza a importância de se priorizar a avaliação de riscos antes de iniciar uma operação, garantindo que os riscos sejam reduzidos antes da operação.
#
#    PPL              = 4.11
#    BLEU             = 15.48
#    ROUGE-L F1       = 0.317
#    Faithfulness     = 0.500
#    Answer Relevance = 0.333
#    Plan Adherence   = 0.500

# %% [markdown]
# ## 📝 Célula 15 — Relatório Final
#
# Geração automática de um relatório de texto com interpretação dos resultados.

# %%
# ============================================================
#  RELATÓRIO FINAL AUTOMÁTICO
# ============================================================

def interpret(metric: str, value: float) -> str:
    thresholds = {
        'rouge'       : [(0.5, '🟢 Bom'), (0.3, '🟡 Moderado'), (0, '🔴 Fraco')],
        'faith_rel_pl': [(0.7, '🟢 Bom'), (0.4, '🟡 Moderado'), (0, '🔴 Fraco')],
        'bleu'        : [(30,  '🟢 Bom'), (15,  '🟡 Moderado'), (0, '🔴 Fraco')],
    }
    key = 'bleu' if metric == 'bleu' else (
          'rouge' if 'rouge' in metric else 'faith_rel_pl'
    )
    for threshold, label in thresholds[key]:
        if value >= threshold:
            return label
    return '🔴 Fraco'

mean_r1 = np.mean(rouge_f1_1)
mean_r2 = np.mean(rouge_f1_2)
mean_rL = np.mean(rouge_f1_L)
mean_bl = np.mean(bleu_per_sample)
mean_fa = np.mean(faithfulness_scores)
mean_re = np.mean(relevance_scores)
mean_pl = np.mean(plan_scores)

print('=' * 65)
print('         📋  RELATÓRIO DE AVALIAÇÃO — MODELO FINE-TUNED')
print('=' * 65)
#print(f'  Modelo Base     : distilgpt2')
print(f'  Modelo Base     : {MODEL_BASE}')
print(f'  Adaptador       : LoRA  ({LORA_MODEL_PATH})')
print(f'  Dataset         : {DATASET_PATH}  ({len(samples)} amostras)')
print(f'  Dispositivo     : {DEVICE}')
print('=' * 65)
print()
print(f'  PERPLEXIDADE (PPL)')
print(f'    Média : {np.mean(ppl_scores):.2f}  —  PPL menor = modelo mais previsível')
print()
print(f'  BLEU')
print(f'    Corpus Score : {bleu_results["bleu_score"]:.2f}  {interpret("bleu", bleu_results["bleu_score"])}')
print(f'    Média por amostra : {mean_bl:.2f}')
print()
print(f'  ROUGE')
print(f'    ROUGE-1 F1 : {mean_r1:.3f}  {interpret("rouge1", mean_r1)}')
print(f'    ROUGE-2 F1 : {mean_r2:.3f}  {interpret("rouge2", mean_r2)}')
print(f'    ROUGE-L F1 : {mean_rL:.3f}  {interpret("rougeL", mean_rL)}')
print()
print(f'  FIDELIDADE (FAITHFULNESS)')
print(f'    Média : {mean_fa:.3f}  {interpret("faithfulness", mean_fa)}')
print()
print(f'  RELEVÂNCIA DA RESPOSTA (ANSWER RELEVANCE)')
print(f'    Média : {mean_re:.3f}  {interpret("relevance", mean_re)}')
print()
print(f'  ADERÊNCIA AO PLANO (PLAN ADHERENCE)')
print(f'    Média : {mean_pl:.3f}  {interpret("plan", mean_pl)}')
print()
print('─' * 65)
print('  💡 ANÁLISE GLOBAL:')
print(f'     O modelo apresenta PPL={np.mean(ppl_scores):.1f}, indicando',
      'boa' if np.mean(ppl_scores) < 50 else 'moderada', 'fluência.')
print(f'     As métricas de sobreposição léxica (BLEU/ROUGE) refletem')
print(f'     o grau de fidelidade ao texto de referência.')
print(f'     Faithfulness={mean_fa:.2f} e Plan Adherence={mean_pl:.2f} indicam')
print(f'     se o modelo é adequado para pipelines RAG e agentes.')
print('=' * 65)
# Out:
# =================================================================
#          📋  RELATÓRIO DE AVALIAÇÃO — MODELO FINE-TUNED
# =================================================================
#   Modelo Base     : TinyLlama/TinyLlama-1.1B-Chat-v1.0
#   Adaptador       : LoRA  (lora_finetuned_model)
#   Dataset         : /content/dataset.jsonl  (416 amostras)
#   Dispositivo     : cuda
# =================================================================
#
#   PERPLEXIDADE (PPL)
#     Média : 3.06  —  PPL menor = modelo mais previsível
#
#   BLEU
#     Corpus Score : 8.93  🔴 Fraco
#     Média por amostra : 9.40
#
#   ROUGE
#     ROUGE-1 F1 : 0.320  🟡 Moderado
#     ROUGE-2 F1 : 0.166  🔴 Fraco
#     ROUGE-L F1 : 0.260  🔴 Fraco
#
#   FIDELIDADE (FAITHFULNESS)
#     Média : 0.771  🟢 Bom
#
#   RELEVÂNCIA DA RESPOSTA (ANSWER RELEVANCE)
#     Média : 0.480  🟡 Moderado
#
#   ADERÊNCIA AO PLANO (PLAN ADHERENCE)
#     Média : 0.493  🟡 Moderado
#
# ─────────────────────────────────────────────────────────────────
#   💡 ANÁLISE GLOBAL:
#      O modelo apresenta PPL=3.1, indicando boa fluência.
#      As métricas de sobreposição léxica (BLEU/ROUGE) refletem
#      o grau de fidelidade ao texto de referência.
#      Faithfulness=0.77 e Plan Adherence=0.49 indicam
#      se o modelo é adequado para pipelines RAG e agentes.
# =================================================================

# %% [markdown]
# ## 💾 Célula 16 — Exportar Resultados
#
# Salvamos os resultados detalhados em CSV e o gráfico em PNG.

# %%
# ============================================================
#  EXPORTAR RESULTADOS
# ============================================================

# CSV detalhado com respostas geradas
df_export = df_results.copy()
df_export['Gerado']    = generated_responses
df_export['Referência'] = reference_outputs

CSV_PATH = 'resultados_avaliacao.csv'
df_export.to_csv(CSV_PATH, index=False, encoding='utf-8-sig')

print(f'✅ Resultados exportados:')
print(f'   📄 {CSV_PATH}           — métricas por amostra + textos')
print(f'   🖼️  avaliacao_metricas.png — visualizações')
print()
print('🎉 Avaliação concluída! Todos os artefatos foram gerados.')
# Out:
# ✅ Resultados exportados:
#    📄 resultados_avaliacao.csv           — métricas por amostra + textos
#    🖼️  avaliacao_metricas.png — visualizações
#
# 🎉 Avaliação concluída! Todos os artefatos foram gerados.

# %% [markdown]
# ---
#
# ## 📚 Referências e Próximos Passos
#
# ### Referências
# | Recurso | Link |
# |---|---|
# | BLEU original | Papineni et al., 2002 |
# | ROUGE original | Lin, 2004 |
# | Perplexidade | Jelinek et al., 1977 |
# | RAGAs (Faithfulness/Relevance) | [github.com/explodinggradients/ragas](https://github.com/explodinggradients/ragas) |
# | LoRA | Hu et al., 2021 |
#
# ### Próximos Passos Sugeridos
#
# 1. **Faithfulness com NLI**: substituir a abordagem léxica por um modelo DeBERTa treinado em NLI.
# 2. **LLM-as-judge**: usar GPT-4 ou Claude para avaliar Relevância e Plan Adherence de forma semântica.
# 3. **RAGAs**: integrar o framework [RAGAs](https://github.com/explodinggradients/ragas) para avaliação automatizada de pipelines RAG.
# 4. **Comparação baseline**: avaliar o `distilgpt2` sem LoRA e comparar com o fine-tuned para quantificar o ganho.
# 5. **Human Evaluation**: coletar avaliações humanas para validar as métricas automáticas.
